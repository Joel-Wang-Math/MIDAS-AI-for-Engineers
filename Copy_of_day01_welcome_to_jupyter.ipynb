# %% [markdown]
# <a href="https://colab.research.google.com/github/Joel-Wang-Math/MIDAS-AI-for-Engineers/blob/main/Copy_of_day01_welcome_to_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Summer School!
#
# In this notebook, we'll get to know **Jupyter notebooks** — an interactive environment that lets you combine text, code, and figures in one document. We'll also learn the basics of the **Python** programming language.
#
# Each section below contains a mix of explanations and code cells. To run a code cell, click on it and press **Shift + Enter**.

# %%
# This is a block of Python code. You can run it by clicking the play button.
# this is a comment.
# print("I love cats.")
print("I love dogs.")
# Out:
# I love dogs.

# %% [markdown]
# One of the trickiest aspects of Jupyter notebooks for beginners is _making sure you run your code._ It's not enough to _write_ code in a code cell. It has to be executed! You can do that by clicking the "play" icon on a cell.
#
# If you only run the code in the second cell below without running the first, you'll get an error- because as far as Python knows, the variable `my_first_variable` has never been created.

# %%
my_first_variable = 7 + 7

# %%
my_first_variable
# Out:
# 14

# %% [markdown]
# ### Try it: What happens when you skip a cell?
#
# Let's see this in action. First, **restart your kernel** (Runtime > Restart session in Colab, or Kernel > Restart in JupyterLab). Then run **only the second** code cell below — skip the first one.
#
# Read the error message carefully. You'll see this kind of error a lot today!

# %%
step_one = 10 * 5

# %%
print(f"The answer is {step_one}")
# Out:
# The answer is 50

# %% [markdown]
# Did you get a `NameError`? That's Python telling you: *"I don't know what `step_one` is, because you never ran the cell that created it."*
#
# Now go back and run **both cells** in order, top to bottom. The error goes away.
#
# **The rule:** writing code in a cell is not enough — you have to **execute** it (Shift+Enter) for Python to know about it.

# %% [markdown]
# ## Common data types in Python
#  Let's see a few very common ways data can be represented in Python.

# %% [markdown]
# ### Integers
# An integer is a whole number, like 0, 1, 2 or 3.

# %%
a = 1
b = 2

# %%
type(a)
# Out:
# int

# %%
a + b
# Out:
# 3

# %% [markdown]
# ### Decimal numbers
# In Python, decimal numbers (like 3.14) are called _floats_ (short for "floating point decimal").

# %%
c = 3.14
d = 1.618
e = 1.0

# %%
type(c)
# Out:
# float

# %%
c * d
# Out:
# 5.080520000000001

# %% [markdown]
# **🤔 Guess first:** `a` is an integer (`1`) and `c` is a float (`3.14`). Before you run the next cell, predict two things: what value will `a + c` produce, and will the result be an `int` or a `float`? Run the cell, then check your second prediction with `type(a + c)`.

# %%
a + c
# Out:
# 4.140000000000001

# %% [markdown]
# ### Strings
# We can also work with sequences of characters, called _strings_.

# %%
greeting = "hello"
name = "world"

# %%
type(greeting)
# Out:
# str

# %%
greeting + " " + name
# Out:
# 'hello world'

# %% [markdown]
# ### Lists
# You can keep a collection of several values in a _list_.

# %%
list_of_integers = [1, 2, 3, 4, 5]
list_of_strings = ["hello", "world", "this", "is", "a", "list"]

# %% [markdown]
# **🤔 Guess first:** `list_of_strings` contains `["hello", "world", "how", "are", "you", "today"]`. Before running the next cell, predict which word `list_of_strings[5]` will give you. Is it the 5th word? Run it and see.

# %%
list_of_strings[5]
# Out:
# 'list'

# %% [markdown]
# Notice we used index `5` to get the **6th** element. Python uses **zero-based indexing** — the first element is at index `0`, the second at index `1`, and so on.

# %% [markdown]
# ### Dictionaries
# You can store key-value pairs in a _dictionary_.

# %%
grocery_cart = {"oranges": 1, "apples": 2, "pears": 3}

# %%
grocery_cart
# Out:
# {'oranges': 1, 'apples': 2, 'pears': 3}

# %%
grocery_cart["apples"]
# Out:
# 2

# %% [markdown]
# ## A few Python functions
# You can do a limitless variety of computations in Python. Here are a few basics to get you started.

# %%
# Print to output
print(greeting)
greeting
# Out:
# hello
# 'hello'

# %%
# Get the type of a variable
type(greeting)
# Out:
# str

# %%
# Add up a list of values
sum(list_of_integers)
# Out:
# 15

# %%
# Get the length of a list
len(list_of_strings)
# Out:
# 6

# %%
# Arithmetic operations
my_result = a - b + (c / d) * 10

# %%
# You can also define your own function.
def which_is_bigger(a, b):
    if a > b:
        return a
    else:
        return b

# %%
max(list_of_integers)
# Out:
# 5

# %%
which_is_bigger(1, 2)
# Out:
# 2

# %%
for item in list_of_strings:
  print(item)
# Out:
# hello
# world
# this
# is
# a
# list

# %% [markdown]
# ## Breaking the Python rules
# Like all programming languages, Python has rules, and if you break them it will let you know.
#
# **🤔 Guess first:** Before running the next cell, predict — will it run successfully, or raise an error? (Hint: what does `str(7)` do?)

# %%
"hello" + str(7)
# Out:
# 'hello7'

# %% [markdown]
# **🤔 Guess first:** The function `which_is_bigger` was defined with exactly two parameters. Predict what happens when we call it with **three** arguments — and if you think it's an error, guess what the error message will say. Then run the cell and check.

# %%
# This will cause an error — the function expects exactly 2 arguments
which_is_bigger(1, 2, 3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_1490/3661734463.py in <cell line: 0>()
#       1 # This will cause an error — the function expects exactly 2 arguments
# ----> 2 which_is_bigger(1, 2, 3)
#
# TypeError: which_is_bigger() takes 2 positional arguments but 3 were given

# %% [markdown]
# ### Notebook gotcha: Out-of-order execution
#
# Notebooks let you run cells in **any order**. This is powerful, but it can cause confusing bugs. Try this experiment (the code cells below are labeled **Cell 1**, **Cell 2**, and **Cell 3** so you can tell them apart):
#
# 1. Run the **first two cells** below **in order** — you should see `Total is 30`.
# 2. Now go back and run **only Cell 3** (`price = 99`).
# 3. **🤔 Guess first:** before re-running **Cell 2**, predict what `total` will be.
# 4. Re-run **Cell 2**. Was your prediction right?

# %%
# Cell 1
price = 10

# %%
# Cell 2
total = price * 3
print(f"Total is {total} — is that what you expected?")
# Out:
# Total is 30 — is that what you expected?

# %%
# Cell 3
price = 99

# %% [markdown]
# The value of `total` depends on which `price` cell you ran **most recently**, not which one appears first in the notebook. This is called **stale state** — a variable holds a value you didn't expect because cells were run out of order.
#
# When you get a surprising result, ask yourself: *"Did I run these cells in order from top to bottom?"*
#
# A quick fix: **Kernel > Restart & Run All** (or **Runtime > Restart and run all** in Colab) re-runs everything top-to-bottom, clearing out any stale state.

# %%
# Python's string module has useful constants like the alphabet
import string
alphabet = list(string.ascii_lowercase)
print("The 14th letter is:", alphabet[13])
# Out:
# The 14th letter is: n

# %% [markdown]
# ## Exercises
#
# Try these on your own! Replace `<YOUR OWN CODE>` with your answer.

# %% [markdown]
# **Exercise 1:** Create a variable called `my_name` that stores your name as a string. Then print it.

# %%
# Your code here

# %% [markdown]
# **Exercise 2:** Create a list of 5 numbers. Then use `sum()` and `len()` to compute the average.

# %%
# Your code here

# %% [markdown]
# **Exercise 3:** Create a dictionary that maps three of your favorite foods to a rating from 1-10. Then look up the rating for one of them.

# %%
# Your code here

# %% [markdown]
# ## Key Points
#
# - Jupyter notebooks combine text and code in one document. Run cells with **Shift + Enter**.
# - Python has several core data types: `int`, `float`, `str`, `list`, and `dict`.
# - Python uses **zero-based indexing** — the first element is at index `0`.
# - You can define reusable logic with **functions** using `def`.
# - Error messages are your friend — read them carefully to understand what went wrong.
# - When things go wrong, try **Kernel > Restart & Run All** (or Runtime > Restart and run all in Colab) — this resets everything and runs cells top-to-bottom, eliminating stale-state bugs.
