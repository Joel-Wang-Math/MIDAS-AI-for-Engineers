# %% [markdown]
# <a href="https://colab.research.google.com/github/Joel-Wang-Math/MIDAS-AI-for-Engineers/blob/main/Copy_of_day04_part2a_groq_sandbox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Day 4, Part 2a: The Groq Sandbox
#
# **MIDAS Summer Academy**
#
# This is a playground. The goal is to get comfortable calling a large language model through the Groq API and to build intuition for how the call's **parameters** and your **prompt** change what you get back.

# %% [markdown]
# ## Setup
#
# ### Step 1: Install the Groq client

# %%
# !pip install -q groq

# %% [markdown]
# ### Step 2: Create a client with your API key
#
# You made a free key at [console.groq.com/keys](https://console.groq.com/keys). Paste it when prompted; it is not stored in the notebook.

# %%
from getpass import getpass
from groq import Groq

client = Groq(api_key=getpass("midas-academy"))
print("Client ready.")
# Out:
# midas-academy··········
# Client ready.

# %% [markdown]
# ## Calling the model
#
# This is close to the sample code the Groq console gives you. You send a list of messages and some parameters; the response comes back as a `completion` object, and the model's text is inside it.

# %%
completion = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[
      {
        "role": "user",
        "content": "To be, or not to be?"
      }
    ],
    temperature=2,
    max_completion_tokens=1024,
    top_p=1,
)

print(completion.choices[0].message.content)
# Out:
# To which 'to be and not be,' the question is most famous to refer?
#
# 1.) To Hamlet to not to take on his fate. As he grapples with his desire for death or the reality of life - from "The Tragedy of Hamlet Prince of Denmark," the famous tragedy written by "Bard of Avon."
#
# In the famous monologue of the play that you allude to it starts,
#
# 'Thesis: Shall our prince take that leap from mortality.'
#
# 'The Antithesis: No! That would only prove cowardice.'
#
# The play ends in the destruction of not just a man and his friends, but a corrupt Denmark ruled by tyrant. And a corrupt Norway, also suffering with this corrupt government in the land of Scandanavia's "Denmark & Northern Sweden Norway", "Scandinavian Peninsula.

# %% [markdown]
# # Some experiments to try
#
# ## Modify parameters of the call
# What happens if you change:
#
# - the prompt (`content`)?
# - temperature? Run the *same* prompt three times at `temperature=0`, then three times at `temperature=1.5`. What differs between runs?
# - `max_completion_tokens` (try changing it to a smaller value)
#
# ## Investigate the model output
# You might also investigate what is coming OUT of the model. What is `completion`? What is in `completion.choices[0]` besides the message?
#
# ## Try some prompting recommendations
# Take a look at Groq's [suggestions for prompting here](https://console.groq.com/docs/prompting) and experiment with some of their recommendations.
